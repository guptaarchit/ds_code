# %%
import pandas as pd
import numpy as np

# %%
x = pd.DataFrame({'x': [1, 2, 3], 'y': [3, 4, 5]})
x
# Out:
#    x  y
# 0  1  3
# 1  2  4
# 2  3  5

# %%
a = False or "s"
a
# Out:
# 's'

# %%
ts = pd.Series(np.random.randn(1000),index=pd.date_range('1/1/2000', periods=1000))
ts.cumsum().plot()

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df2.plot(kind='bar', stacked=True)

# %%
df = pd.DataFrame(np.random.rand(1, 4), columns=['a', 'b', 'c', 'd'])
df.head()
# Out:
#           a         b         c         d
# 0  0.333898  0.355178  0.000692  0.200432

# %%
df.plot.scatter(x='a', y='b');

# %%
list('abcde')
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
import numba

# %%
arr = np.random.randn(10)

# %%
arr[2:-2] = np.nan

# %%
s = pd.Series(arr)
s
# Out:
# 0   -0.042501
# 1    0.715714
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8    1.531113
# 9   -0.362823
# dtype: float64

# %%
df = pd.read_csv('twitter sentiment analysis/training.csv', encoding = 'ISO-8859-1', header=None, usecols=[0,2,4,5],
     names=['target','date','user','tweet'],index_col=False)[::30]
df.head(20)
# Out:
#      target                          date             user  \
# 0         0  Mon Apr 06 22:19:45 PDT 2009  _TheSpecialOne_
# 30        0  Mon Apr 06 22:21:07 PDT 2009        fatkat309
# 60        0  Mon Apr 06 22:22:52 PDT 2009    xVivaLaJuicyx
# 90        0  Mon Apr 06 22:26:10 PDT 2009       RU_it_girl
# 120       0  Mon Apr 06 22:27:21 PDT 2009           JenBah
# 150       0  Mon Apr 06 22:28:32 PDT 2009         AKyarnie
# 180       0  Mon Apr 06 22:31:59 PDT 2009        fatkat309
# 210       0  Mon Apr 06 22:33:32 PDT 2009          Mirlina
# 240       0  Mon Apr 06 22:36:03 PDT 2009         omgitsjo
# 270       0  Mon Apr 06 22:37:46 PDT 2009      flowerlilly
# 300       0  Mon Apr 06 22:40:38 PDT 2009         BATMANNN
# 330       0  Mon Apr 06 22:42:06 PDT 2009       sprtsgrl04
# 360       0  Mon Apr 06 22:43:43 PDT 2009        bonerjamz
# 390       0  Mon Apr 06 22:46:22 PDT 2009   cristinesantos
# 420       0  Mon Apr 06 22:48:17 PDT 2009        beccaomgz
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53334 entries, 0 to 1599990
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  53334 non-null  int64
#  1   date    53334 non-null  object
#  2   user    53334 non-null  object
#  3   tweet   53334 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 1.6+ MB

# %%
df['target'].unique()
# Out:
# array([0, 4], dtype=int64)

# %%
pdf = df[:20]
pdf
# Out:
#      target                          date             user  \
# 0         0  Mon Apr 06 22:19:45 PDT 2009  _TheSpecialOne_
# 30        0  Mon Apr 06 22:21:07 PDT 2009        fatkat309
# 60        0  Mon Apr 06 22:22:52 PDT 2009    xVivaLaJuicyx
# 90        0  Mon Apr 06 22:26:10 PDT 2009       RU_it_girl
# 120       0  Mon Apr 06 22:27:21 PDT 2009           JenBah
# 150       0  Mon Apr 06 22:28:32 PDT 2009         AKyarnie
# 180       0  Mon Apr 06 22:31:59 PDT 2009        fatkat309
# 210       0  Mon Apr 06 22:33:32 PDT 2009          Mirlina
# 240       0  Mon Apr 06 22:36:03 PDT 2009         omgitsjo
# 270       0  Mon Apr 06 22:37:46 PDT 2009      flowerlilly
# 300       0  Mon Apr 06 22:40:38 PDT 2009         BATMANNN
# 330       0  Mon Apr 06 22:42:06 PDT 2009       sprtsgrl04
# 360       0  Mon Apr 06 22:43:43 PDT 2009        bonerjamz
# 390       0  Mon Apr 06 22:46:22 PDT 2009   cristinesantos
# 420       0  Mon Apr 06 22:48:17 PDT 2009        beccaomgz
# ...

# %%
pdf.iloc[0:30]
# Out:
#      target                          date             user  \
# 0         0  Mon Apr 06 22:19:45 PDT 2009  _TheSpecialOne_
# 30        0  Mon Apr 06 22:21:07 PDT 2009        fatkat309
# 60        0  Mon Apr 06 22:22:52 PDT 2009    xVivaLaJuicyx
# 90        0  Mon Apr 06 22:26:10 PDT 2009       RU_it_girl
# 120       0  Mon Apr 06 22:27:21 PDT 2009           JenBah
# 150       0  Mon Apr 06 22:28:32 PDT 2009         AKyarnie
# 180       0  Mon Apr 06 22:31:59 PDT 2009        fatkat309
# 210       0  Mon Apr 06 22:33:32 PDT 2009          Mirlina
# 240       0  Mon Apr 06 22:36:03 PDT 2009         omgitsjo
# 270       0  Mon Apr 06 22:37:46 PDT 2009      flowerlilly
# 300       0  Mon Apr 06 22:40:38 PDT 2009         BATMANNN
# 330       0  Mon Apr 06 22:42:06 PDT 2009       sprtsgrl04
# 360       0  Mon Apr 06 22:43:43 PDT 2009        bonerjamz
# 390       0  Mon Apr 06 22:46:22 PDT 2009   cristinesantos
# 420       0  Mon Apr 06 22:48:17 PDT 2009        beccaomgz
# ...

# %%
pdf.loc[0:30]
# Out:
#     target                          date             user  \
# 0        0  Mon Apr 06 22:19:45 PDT 2009  _TheSpecialOne_
# 30       0  Mon Apr 06 22:21:07 PDT 2009        fatkat309
#
#                                                 tweet
# 0   @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 30  some1 hacked my account on aim  now i have to ...

# %%
pdf.loc[df.user=='missria', ['tweet']]
# Out:
#                                                  tweet
# 450  can't believe it! I'm in disbelief of it all i...

# %%
d = pd.DataFrame([True,True])
pdf.where(d, 'user') #basically a filter kind of thing
# Out:
#     target  date  user tweet
# 0     user  user  user  user
# 30    user  user  user  user
# 60    user  user  user  user
# 90    user  user  user  user
# 120   user  user  user  user
# 150   user  user  user  user
# 180   user  user  user  user
# 210   user  user  user  user
# 240   user  user  user  user
# 270   user  user  user  user
# 300   user  user  user  user
# 330   user  user  user  user
# 360   user  user  user  user
# 390   user  user  user  user
# 420   user  user  user  user
# 450   user  user  user  user
# 480   user  user  user  user
# 510   user  user  user  user
# 540   user  user  user  user
# 570   user  user  user  user

# %%
pdf.query(expr='user == "missria"')
# Out:
#      target                          date     user  \
# 450       0  Mon Apr 06 22:51:00 PDT 2009  missria
#
#                                                  tweet
# 450  can't believe it! I'm in disbelief of it all i...

# %%
pdf.sort_values('user', ascending=False)
# Out:
#      target                          date             user  \
# 60        0  Mon Apr 06 22:22:52 PDT 2009    xVivaLaJuicyx
# 510       0  Mon Apr 06 22:55:30 PDT 2009       vibratoria
# 330       0  Mon Apr 06 22:42:06 PDT 2009       sprtsgrl04
# 480       0  Mon Apr 06 22:52:25 PDT 2009        rachelgab
# 540       0  Mon Apr 06 22:57:07 PDT 2009      omgwtfannie
# 240       0  Mon Apr 06 22:36:03 PDT 2009         omgitsjo
# 450       0  Mon Apr 06 22:51:00 PDT 2009          missria
# 270       0  Mon Apr 06 22:37:46 PDT 2009      flowerlilly
# 180       0  Mon Apr 06 22:31:59 PDT 2009        fatkat309
# 30        0  Mon Apr 06 22:21:07 PDT 2009        fatkat309
# 390       0  Mon Apr 06 22:46:22 PDT 2009   cristinesantos
# 360       0  Mon Apr 06 22:43:43 PDT 2009        bonerjamz
# 420       0  Mon Apr 06 22:48:17 PDT 2009        beccaomgz
# 0         0  Mon Apr 06 22:19:45 PDT 2009  _TheSpecialOne_
# 90        0  Mon Apr 06 22:26:10 PDT 2009       RU_it_girl
# ...

# %%
pdf.user.isin(['JenBah','Mirlina'])
# Out:
# 0      False
# 30     False
# 60     False
# 90     False
# 120     True
# 150    False
# 180    False
# 210     True
# 240    False
# 270    False
# 300    False
# 330    False
# 360    False
# 390    False
# 420    False
# 450    False
# 480    False
# 510    False
# 540    False
# 570    False
# Name: user, dtype: bool

# %%
pdf.user.apply(lambda x: x.lower())
pdf
# Out:
#      target                          date             user  \
# 0         0  Mon Apr 06 22:19:45 PDT 2009  _TheSpecialOne
# %%
sdf
# Out:
#    row  One_X  One_Y  Two_X  Two_Y
# 0    0    1.1    1.2   1.11   1.22
# 1    1    1.1    1.2   1.11   1.22
# 2    2    1.1    1.2   1.11   1.22

# %%
sdf = sdf.stack(level=-1)

# %%
sdf[0][1]
# Out:
# 1.1

# %%
s = sdf.unstack()

# %%
s
# Out:
#    row  One_X  One_Y  Two_X  Two_Y
# 0  0.0    1.1    1.2   1.11   1.22
# 1  1.0    1.1    1.2   1.11   1.22
# 2  2.0    1.1    1.2   1.11   1.22

# %%
s = s.unstack()
s
# Out:
# row    0    0.00
#        1    1.00
#        2    2.00
# One_X  0    1.10
#        1    1.10
#        2    1.10
# One_Y  0    1.20
#        1    1.20
#        2    1.20
# Two_X  0    1.11
#        1    1.11
#        2    1.11
# Two_Y  0    1.22
#        1    1.22
#        2    1.22
# dtype: float64

# %%
f = pd.DataFrame({'foo': ['one', 'one', 'one', 'two', 'two', 'two'],
                   'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
                   'baz': [1, 1, 3, 4, 5, 6],
                   'zoo': ['x', 'y', 'z', 'q', 'w', 't']})
f
# Out:
#    foo bar  baz zoo
# 0  one   A    1   x
# 1  one   B    1   y
# 2  one   C    3   z
# 3  two   A    4   q
# 4  two   B    5   w
# 5  two   C    6   t

# %%
f.pivot(index='foo', columns='bar', values='baz')
# Out:
# bar  A  B  C
# foo
# one  1  1  3
# two  4  5  6

# %%
rng = pd.date_range('2000-01-01', periods=6)

df1 = pd.DataFrame(np.random.randn(6, 3), index=rng, columns=['A', 'B', 'C'])

# %%
df1
# Out:
#                    A         B         C
# 2000-01-01 -1.949447 -0.736699  0.429820
# 2000-01-02  0.231298  1.763922  0.149223
# 2000-01-03 -0.289478 -0.005927 -0.894024
# 2000-01-04 -0.789329 -0.063795 -0.192194
# 2000-01-05  1.001952  0.449410 -1.313731
# 2000-01-06  0.563066  1.076473  0.582147

# %%
df2 = df1.copy()

# %%
df = df1.append(df2, verify_integrity=True, ignore_index=True)
df
# Out:
#            A         B         C
# 0  -1.949447 -0.736699  0.429820
# 1   0.231298  1.763922  0.149223
# 2  -0.289478 -0.005927 -0.894024
# 3  -0.789329 -0.063795 -0.192194
# 4   1.001952  0.449410 -1.313731
# 5   0.563066  1.076473  0.582147
# 6  -1.949447 -0.736699  0.429820
# 7   0.231298  1.763922  0.149223
# 8  -0.289478 -0.005927 -0.894024
# 9  -0.789329 -0.063795 -0.192194
# 10  1.001952  0.449410 -1.313731
# 11  0.563066  1.076473  0.582147

# %%
df.describe()
# Out:
#                A          B          C
# count  12.000000  12.000000  12.000000
# mean   -0.205323   0.413897  -0.206460
# std     1.011631   0.851859   0.720134
# min    -1.949447  -0.736699  -1.313731
# 25%    -0.789329  -0.063795  -0.894024
# 50%    -0.029090   0.221742  -0.021485
# 75%     0.563066   1.076473   0.429820
# max     1.001952   1.763922   0.582147

# %%
f = pd.DataFrame({'foo': ['one', 'one', 'one', 'two', 'two', 'two'],
                   'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
                   'baz': [1, 1, 3, 4, 5, 6],
                   'zoo': ['x', 'y', 'z', 'q', 'w', 't']})
f
# Out:
#    foo bar  baz zoo
# 0  one   A    1   x
# 1  one   B    1   y
# 2  one   C    3   z
# 3  two   A    4   q
# 4  two   B    5   w
# 5  two   C    6   t

# %%
a = f.groupby('foo')

# %%
a.sum()
# Out:
#      baz
# foo
# one    5
# two   15

# %%
f.to_csv('test.csv')

# %%
f.to_excel('test.xlsx', sheet_name='test')

# %%
s = pd.Series([1,2,3,4,[3,6,78]])
s
# Out:
# 0             1
# 1             2
# 2             3
# 3             4
# 4    [3, 6, 78]
# dtype: object

# %%
f.to_numpy()
# Out:
# array([['one', 'A', 1, 'x'],
#        ['one', 'B', 1, 'y'],
#        ['one', 'C', 3, 'z'],
#        ['two', 'A', 4, 'q'],
#        ['two', 'B', 5, 'w'],
#        ['two', 'C', 6, 't']], dtype=object)

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.1.0

# %%
dti = pd.date_range('2018-01-01', periods=3, freq='H')
dti
# Out:
# DatetimeIndex(['2018-01-01 00:00:00', '2018-01-01 01:00:00',
#                '2018-01-01 02:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
import datetime
dtf = pd.to_datetime(['1/1/2018', np.datetime64('2018-01-01'),datetime.datetime(2018, 1, 1)])
dtf
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-01', '2018-01-01'], dtype='datetime64[ns]', freq=None)

# %%
c = pd.Categorical(['a', 'b', 'c', 'a', 'b', 'c'], ordered=True,
                   categories=['a','c', 'b'])
c
# Out:
# ['a', 'b', 'c', 'a', 'b', 'c']
# Categories (3, object): ['a' < 'c' < 'b']

# %%
c.min()
# Out:
# 'a'
